# %%
import numpy as np
import pandas as pd

# %%
issues1=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=1&since=\"2019-06-01T10:00:00Z\"&per_page=400")
issues2=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=2&since=\"2019-06-01T10:00:00Z\"&per_page=400")
issues3=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=3&since=\"2019-06-01T10:00:00Z\"&per_page=400")
#issues4=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=4&since=\"2019-06-01T10:00:00Z\"&per_page=400")
#issues5=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=5&since=\"2019-06-01T10:00:00Z\"&per_page=400")
frames = [issues1, issues2, issues3]

issues = pd.concat(frames)

# %%
issues.count()
# Out:
# url                         286
# repository_url              286
# labels_url                  286
# comments_url                286
# events_url                  286
# html_url                    286
# id                          286
# node_id                     286
# number                      286
# title                       286
# user                        286
# labels                      286
# state                       286
# locked                      286
# assignee                     96
# assignees                   286
# milestone                     0
# comments                    286
# created_at                  286
# updated_at                  286
# closed_at                   286
# author_association          286
# active_lock_reason            0
# draft                       150
# pull_request                150
# body                        276
# reactions                   286
# timeline_url                286
# performed_via_github_app      0
# state_reason                136
# dtype: int64

# %%
closedissues=issues[(issues['state']=="closed") & (issues['pull_request'].isnull())]
closedissues[['number','title','closed_at']]
# Out:
#     number                                              title  \
# 5      601            Check python bindings of MorphSpotClean
# 11     576            Handle default sample/pixel in ReadTIFF
# 14     571                              Problem building NIQA
# 15     568                                     Clean up cmake
# 16     567                    User defined acquisition angles
# ..     ...                                                ...
# 81      39                Morph spot clean performance tuning
# 82      23             Config files compatible cross platform
# 83      15  ImageviewerWidget: Tooltip coordinates in Zoom...
# 84      14          ImageviewerWidget: ROIs with Zoom and Pan
# 85       3                  MuhRec - saving 8-bit TIFF images
#
#                    closed_at
# 5  2023-09-12 05:51:10+00:00
# 11 2023-04-18 10:40:11+00:00
# 14 2023-01-10 08:46:06+00:00
# 15 2023-01-17 20:33:50+00:00
# 16 2022-11-29 06:26:11+00:00
# ..                       ...
# 81 2020-01-10 11:03:56+00:00
# 82 2019-12-10 07:51:50+00:00
# 83 2021-12-07 17:43:14+00:00
# 84 2020-03-10 07:58:20+00:00
# 85 2020-06-15 14:51:02+00:00
#
# [136 rows x 3 columns]

# %% [markdown]
# # Print list for github markdown

# %%
for index,issue in closedissues.iterrows() :
    print('- Issue',issue['number'], '- [',issue['title'],'](', issue['html_url'],')')
# Out:
# - Issue 601 - [ Check python bindings of MorphSpotClean ]( https://github.com/neutronimaging/imagingsuite/issues/601 )
# - Issue 576 - [ Handle default sample/pixel in ReadTIFF ]( https://github.com/neutronimaging/imagingsuite/issues/576 )
# - Issue 571 - [ Problem building NIQA ]( https://github.com/neutronimaging/imagingsuite/issues/571 )
# - Issue 568 - [ Clean up cmake ]( https://github.com/neutronimaging/imagingsuite/issues/568 )
# - Issue 567 - [ User defined acquisition angles ]( https://github.com/neutronimaging/imagingsuite/issues/567 )
# - Issue 564 - [ FDK module crashes ]( https://github.com/neutronimaging/imagingsuite/issues/564 )
# - Issue 562 - [ Reading tiff fails ]( https://github.com/neutronimaging/imagingsuite/issues/562 )
# - Issue 559 - [ BB_ext_mask parameter missing in BB dialog ]( https://github.com/neutronimaging/imagingsuite/issues/559 )
# - Issue 558 - [ Add logging to file ]( https://github.com/neutronimaging/imagingsuite/issues/558 )
# - Issue 556 - [ Load module dll fail occasionally on windows ]( https://github.com/neutronimaging/imagingsuite/issues/556 )
# - Issue 554 - [ Add arbitrary images to centering dialog ]( https://github.com/neutronimaging/imagingsuite/issues/554 )
# - Issue 552 - [ Implement an edge interpolation hole filler ]( https://github.com/neutronimaging/imagingsuite/issues/552 )
# - Issue 549 - [ Truncation artefacts ]( https://github.com/neutronimaging/imagingsuite/issues/549 )
# - Issue 543 - [ Parallelise histogram ]( https://github.com/neutronimaging/imagingsuite/issues/543 )
# - Issue 538 - [ MorphSpotClean doesn't filter ]( https://github.com/neutronimaging/imagingsuite/issues/538 )
# - Issue 537 - [ Add averaging to handle low dose projection ]( https://github.com/neutronimaging/imagingsuite/issues/537 )
# - Issue 533 - [ Add build date in the log file ]( https://github.com/neutronimaging/imagingsuite/issues/533 )
# - Issue 530 - [ MuhRec CLI seg faults ]( https://github.com/neutronimaging/imagingsuite/issues/530 )
# - Issue 525 - [ Compile on M1 ]( https://github.com/neutronimaging/imagingsuite/issues/525 )
# - Issue 516 - [ Transfer ReaderGUI to Qt 6.2 ]( https://github.com/neutronimaging/imagingsuite/issues/516 )
# - Issue 515 - [ Transfer PlotTests to Qt 6.2 ]( https://github.com/neutronimaging/imagingsuite/issues/515 )
# - Issue 514 - [ Transfer WidgetTests to Qt 6.2 ]( https://github.com/neutronimaging/imagingsuite/issues/514 )
# - Issue 513 - [ Transfer QtModuleConfigure to Qt 6.2 ]( https://github.com/neutronimaging/imagingsuite/issues/513 )
# - Issue 512 - [ Transfer QtImaging to Qt 6.2 ]( https://github.com/neutronimaging/imagingsuite/issues/512 )
# - Issue 511 - [ Transfer QtAddons to Qt 6.2 ]( https://github.com/neutronimaging/imagingsuite/issues/511 )
# - Issue 504 - [ Add file conversion tool to muhrec ]( https://github.com/neutronimaging/imagingsuite/issues/504 )
# - Issue 502 - [ ProjectionFilterSingle module produces erroneous recon & can't change config ]( https://github.com/neutronimaging/imagingsuite/issues/502 )
# - Issue 500 - [ Clean histogram at new ]( https://github.com/neutronimaging/imagingsuite/issues/500 )
# - Issue 497 - [ Add switch to deactivate circular mask for recon ]( https://github.com/neutronimaging/imagingsuite/issues/497 )
# - Issue 493 - [ Jenkins build issues ]( https://github.com/neutronimaging/imagingsuite/issues/493 )
# - Issue 489 - [ MuhRec doesn't return volume on ubuntu 20.04 ]( https://github.com/neutronimaging/imagingsuite/issues/489 )
# - Issue 488 - [ Update deployment script for MacOS ]( https://github.com/neutronimaging/imagingsuite/issues/488 )
# - Issue 484 - [ Improve morphspotclean ]( https://github.com/neutronimaging/imagingsuite/issues/484 )
# - Issue 481 - [ Implement patch processing in MorphSpotClean ]( https://github.com/neutronimaging/imagingsuite/issues/481 )
# - Issue 478 - [ MuhRec can't reconstruct more slices than the width. ]( https://github.com/neutronimaging/imagingsuite/issues/478 )
# - Issue 477 - [ Dose ROI throw exception when the projection is flipped ]( https://github.com/neutronimaging/imagingsuite/issues/477 )
# - Issue 475 - [ Make FFT thread safe ]( https://github.com/neutronimaging/imagingsuite/issues/475 )
# - Issue 472 - [ Clean up to improve UX ]( https://github.com/neutronimaging/imagingsuite/issues/472 )
# - Issue 468 - [ Implement processing timing log file ]( https://github.com/neutronimaging/imagingsuite/issues/468 )
# - Issue 462 - [ Issue with loading projections when files are numbered 1-2-3-[...]-10-11-... instead of 01-02-... ]( https://github.com/neutronimaging/imagingsuite/issues/462 )
# - Issue 459 - [ Pixel size dialog sensitive to spots ]( https://github.com/neutronimaging/imagingsuite/issues/459 )
# - Issue 456 - [ Golden ratio angles are messed up in muhrec ]( https://github.com/neutronimaging/imagingsuite/issues/456 )
# - Issue 446 - [ Revised golden ratio recons in MuhRec ]( https://github.com/neutronimaging/imagingsuite/issues/446 )
# - Issue 443 - [ Analysing directory content only provides single file ]( https://github.com/neutronimaging/imagingsuite/issues/443 )
# - Issue 442 - [ ROI manager clear ]( https://github.com/neutronimaging/imagingsuite/issues/442 )
# - Issue 439 - [ Polynomial correction fails test ]( https://github.com/neutronimaging/imagingsuite/issues/439 )
# - Issue 432 - [ Move kiptool to its own repos ]( https://github.com/neutronimaging/imagingsuite/issues/432 )
# - Issue 428 - [ Minor release test issues. ]( https://github.com/neutronimaging/imagingsuite/issues/428 )
# - Issue 427 - [ Build problems on Ubuntu ]( https://github.com/neutronimaging/imagingsuite/issues/427 )
# - Issue 425 - [ Image viewer sensitive to nan and inf ]( https://github.com/neutronimaging/imagingsuite/issues/425 )
# - Issue 424 - [ Muhrec crashes at end of recon ]( https://github.com/neutronimaging/imagingsuite/issues/424 )
# - Issue 420 - [ NIQA compile problems ]( https://github.com/neutronimaging/imagingsuite/issues/420 )
# - Issue 418 - [ Problem with boundary check on projection filter ]( https://github.com/neutronimaging/imagingsuite/issues/418 )
# - Issue 414 - [ Add citations to kiptool modules ]( https://github.com/neutronimaging/imagingsuite/issues/414 )
# - Issue 412 - [ KipTool - error configuring modules that require loading images ]( https://github.com/neutronimaging/imagingsuite/issues/412 )
# - Issue 409 - [ Adopt kiptool to new API ]( https://github.com/neutronimaging/imagingsuite/issues/409 )
# - Issue 407 - [ Change label in center dialog ]( https://github.com/neutronimaging/imagingsuite/issues/407 )
# - Issue 406 - [ Recon from list file separator ]( https://github.com/neutronimaging/imagingsuite/issues/406 )
# - Issue 404 - [ CBCT doesn't add any publication  ]( https://github.com/neutronimaging/imagingsuite/issues/404 )
# - Issue 403 - [ Muhrec overall progress not updated correctly ]( https://github.com/neutronimaging/imagingsuite/issues/403 )
# - Issue 402 - [ Muhrec debug messages in the log ]( https://github.com/neutronimaging/imagingsuite/issues/402 )
# - Issue 401 - [ MuhRec Memory limit dialog ]( https://github.com/neutronimaging/imagingsuite/issues/401 )
# - Issue 400 - [ Imageviewer widget histograms ]( https://github.com/neutronimaging/imagingsuite/issues/400 )
# - Issue 393 - [ add lmfit in externals for Win ]( https://github.com/neutronimaging/imagingsuite/issues/393 )
# - Issue 392 - [ MuhRec - config modules receives unprocessed images ]( https://github.com/neutronimaging/imagingsuite/issues/392 )
# - Issue 391 - [ Implement threading in WaveletRingClean ]( https://github.com/neutronimaging/imagingsuite/issues/391 )
# - Issue 381 - [ kipl::base::morphology LabelImage crashes on Win ]( https://github.com/neutronimaging/imagingsuite/issues/381 )
# - Issue 378 - [ Fix build server ]( https://github.com/neutronimaging/imagingsuite/issues/378 )
# - Issue 374 - [ BB - exception is not thrown when automatic segmentation fails ]( https://github.com/neutronimaging/imagingsuite/issues/374 )
# - Issue 371 - [ MuhRec: module dialogs don't open after merging issue123_configfiles ]( https://github.com/neutronimaging/imagingsuite/issues/371 )
# - Issue 370 - [ BB module, add automatic counting of external background images ]( https://github.com/neutronimaging/imagingsuite/issues/370 )
# - Issue 369 - [ Implement wall clock time the timer class ]( https://github.com/neutronimaging/imagingsuite/issues/369 )
# - Issue 368 - [ BB wrong number of ext images does not throw the right exception ]( https://github.com/neutronimaging/imagingsuite/issues/368 )
# - Issue 365 - [ MorphSpotClean crashes on windows ]( https://github.com/neutronimaging/imagingsuite/issues/365 )
# - Issue 360 - [ Add useful constants to be used in the TOF library ]( https://github.com/neutronimaging/imagingsuite/issues/360 )
# - Issue 356 - [ Transfer TNT uses to Armadillo ]( https://github.com/neutronimaging/imagingsuite/issues/356 )
# - Issue 355 - [ Wavelet ring cleaning crashing ]( https://github.com/neutronimaging/imagingsuite/issues/355 )
# - Issue 354 - [ Savitsky-Golay filter ]( https://github.com/neutronimaging/imagingsuite/issues/354 )
# - Issue 352 - [ Implement computation of numerical gradient ]( https://github.com/neutronimaging/imagingsuite/issues/352 )
# - Issue 346 - [ Add roi labels ]( https://github.com/neutronimaging/imagingsuite/issues/346 )
# - Issue 343 - [ Plot widget updates ]( https://github.com/neutronimaging/imagingsuite/issues/343 )
# - Issue 340 - [ Image viewer levels sensitive to nan and inf ]( https://github.com/neutronimaging/imagingsuite/issues/340 )
# - Issue 334 - [ Reconstruction by dilation hangs ]( https://github.com/neutronimaging/imagingsuite/issues/334 )
# - Issue 332 - [ BBmodule - change mempcy with std copy ]( https://github.com/neutronimaging/imagingsuite/issues/332 )
# - Issue 328 - [ Move the recon filter to backprojector ]( https://github.com/neutronimaging/imagingsuite/issues/328 )
# - Issue 322 - [ Slices to multi frame tiff ]( https://github.com/neutronimaging/imagingsuite/issues/322 )
# - Issue 319 - [ KipTool - progress bar when loading data  ]( https://github.com/neutronimaging/imagingsuite/issues/319 )
# - Issue 318 - [ KipTool - BB plugin crashes in the absence of a ROI ]( https://github.com/neutronimaging/imagingsuite/issues/318 )
# - Issue 315 - [ Revise skiplist dialog ]( https://github.com/neutronimaging/imagingsuite/issues/315 )
# - Issue 310 - [ MuhRec - add Exceptions when reference images and projection data have different sizes ]( https://github.com/neutronimaging/imagingsuite/issues/310 )
# - Issue 309 - [ MuhRec - Add multiple core processing ]( https://github.com/neutronimaging/imagingsuite/issues/309 )
# - Issue 308 - [ MuhRec - Crashing after "Get piercing point" ]( https://github.com/neutronimaging/imagingsuite/issues/308 )
# - Issue 307 - [ KipTool - add rotation option  ]( https://github.com/neutronimaging/imagingsuite/issues/307 )
# - Issue 306 - [ Add new defaults to polynomial correction ]( https://github.com/neutronimaging/imagingsuite/issues/306 )
# - Issue 303 - [ golden ratio order ]( https://github.com/neutronimaging/imagingsuite/issues/303 )
# - Issue 301 - [ ImageViewerWidget selection not performing well ]( https://github.com/neutronimaging/imagingsuite/issues/301 )
# - Issue 299 - [ MuhRec doesn't delete CurrentRecon ]( https://github.com/neutronimaging/imagingsuite/issues/299 )
# - Issue 298 - [ PyBind Imaging algorithms ]( https://github.com/neutronimaging/imagingsuite/issues/298 )
# - Issue 297 - [ Modules to produce citations in reporting ]( https://github.com/neutronimaging/imagingsuite/issues/297 )
# - Issue 296 - [ CBCT doesn't return correct attune coefs ]( https://github.com/neutronimaging/imagingsuite/issues/296 )
# - Issue 295 - [ MuhRec: CBCT feedback ]( https://github.com/neutronimaging/imagingsuite/issues/295 )
# - Issue 294 - [ MuhRec - BB plugin option for single external BB images ]( https://github.com/neutronimaging/imagingsuite/issues/294 )
# - Issue 291 - [ BB plugin in KipTool ]( https://github.com/neutronimaging/imagingsuite/issues/291 )
# - Issue 290 - [ Prepare for MuhRec release 4.1 ]( https://github.com/neutronimaging/imagingsuite/issues/290 )
# - Issue 282 - [ Muhrec: implement inspection of references ]( https://github.com/neutronimaging/imagingsuite/issues/282 )
# - Issue 281 - [ MuhRec: Revise center of rotation ]( https://github.com/neutronimaging/imagingsuite/issues/281 )
# - Issue 273 - [ Review how we get more conform to the FAIR principle ]( https://github.com/neutronimaging/imagingsuite/issues/273 )
# - Issue 270 - [ KipTool - configuring processing chain ]( https://github.com/neutronimaging/imagingsuite/issues/270 )
# - Issue 269 - [ Setup CentOS on Jenkins ]( https://github.com/neutronimaging/imagingsuite/issues/269 )
# - Issue 259 - [ KipTool , conversion tool ]( https://github.com/neutronimaging/imagingsuite/issues/259 )
# - Issue 250 - [ PixelIterator returns pixels outside image ]( https://github.com/neutronimaging/imagingsuite/issues/250 )
# - Issue 246 - [ KipTool - single image as input ]( https://github.com/neutronimaging/imagingsuite/issues/246 )
# - Issue 236 - [ NIQA Edge analysis ]( https://github.com/neutronimaging/imagingsuite/issues/236 )
# - Issue 235 - [ NIQA issues Contrast Analysis ]( https://github.com/neutronimaging/imagingsuite/issues/235 )
# - Issue 221 - [ KipTool: progress bar starts at 100% ]( https://github.com/neutronimaging/imagingsuite/issues/221 )
# - Issue 204 - [ Finalize edge sampling for resolution ]( https://github.com/neutronimaging/imagingsuite/issues/204 )
# - Issue 166 - [ User documentation for KipTool ]( https://github.com/neutronimaging/imagingsuite/issues/166 )
# - Issue 162 - [ MuhRec Open saved config doesn't update correctly  ]( https://github.com/neutronimaging/imagingsuite/issues/162 )
# - Issue 149 - [ Support CentOS ]( https://github.com/neutronimaging/imagingsuite/issues/149 )
# - Issue 140 - [ Look for synergies in Bragg edge fitting ]( https://github.com/neutronimaging/imagingsuite/issues/140 )
# - Issue 135 - [ Bragg edge fitting  ]( https://github.com/neutronimaging/imagingsuite/issues/135 )
# - Issue 134 - [ Implement edge function fitting ]( https://github.com/neutronimaging/imagingsuite/issues/134 )
# - Issue 133 - [ Update build server ]( https://github.com/neutronimaging/imagingsuite/issues/133 )
# - Issue 130 - [ CBCT writes detector pixel size in slices ]( https://github.com/neutronimaging/imagingsuite/issues/130 )
# - Issue 124 - [ unsupported geometry type message at reconstruction ]( https://github.com/neutronimaging/imagingsuite/issues/124 )
# - Issue 122 - [ Incompatibility with Linux CentOS ]( https://github.com/neutronimaging/imagingsuite/issues/122 )
# - Issue 120 - [ Recon crash with file list ]( https://github.com/neutronimaging/imagingsuite/issues/120 )
# - Issue 110 - [ Consider using CMake ]( https://github.com/neutronimaging/imagingsuite/issues/110 )
# - Issue 95 - [ ImageViewerWidget data interval with NaNs and Infs ]( https://github.com/neutronimaging/imagingsuite/issues/95 )
# - Issue 88 - [ MuhRec - rotation matrix ]( https://github.com/neutronimaging/imagingsuite/issues/88 )
# - Issue 48 - [ MuhRec - Extend projection preview ]( https://github.com/neutronimaging/imagingsuite/issues/48 )
# - Issue 39 - [ Morph spot clean performance tuning ]( https://github.com/neutronimaging/imagingsuite/issues/39 )
# - Issue 23 - [ Config files compatible cross platform ]( https://github.com/neutronimaging/imagingsuite/issues/23 )
# - Issue 15 - [ ImageviewerWidget: Tooltip coordinates in Zoomed images ]( https://github.com/neutronimaging/imagingsuite/issues/15 )
# - Issue 14 - [ ImageviewerWidget: ROIs with Zoom and Pan ]( https://github.com/neutronimaging/imagingsuite/issues/14 )
# - Issue 3 - [ MuhRec - saving 8-bit TIFF images ]( https://github.com/neutronimaging/imagingsuite/issues/3 )

# %%
i2=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=1&since=\"2019-05-28T10:00:00Z\"&per_page=400")

# %%
for index,issue in i2.iterrows() :
    print('- Issue',issue['number'], '- [',issue['title'],'](', issue['html_url'],')')
