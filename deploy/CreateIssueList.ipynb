# %%
import numpy as np
import pandas as pd

# %%
issues=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=1&since=\"2018-08-01T10:00:00Z\"&per_page=400")

# %%
issues.count()
# Out:
# url                   100
# repository_url        100
# labels_url            100
# comments_url          100
# events_url            100
# html_url              100
# id                    100
# node_id               100
# number                100
# title                 100
# user                  100
# labels                100
# state                 100
# locked                100
# assignee               31
# assignees             100
# milestone               0
# comments              100
# created_at            100
# updated_at            100
# closed_at             100
# author_association    100
# pull_request           59
# body                  100
# dtype: int64

# %%
closedissues=issues[(issues['state']=="closed") & (issues['pull_request'].isnull())]
closedissues[['number','title','closed_at']]
# Out:
#     number                                              title  \
# 7      381   kipl::base::morphology LabelImage crashes on Win
# 11     374  BB - exception is not thrown when automatic se...
# 13     371  MuhRec: module dialogs don't open after mergin...
# 14     370  BB module, add automatic counting of external ...
# 17     365                  MorphSpotClean crashes on windows
# 20     360  Add useful constants to be used in the TOF lib...
# 24     355                     Wavelet ring cleaning crashing
# 26     352        Implement computation of numerical gradient
# 31     346                                     Add roi labels
# 34     343                                Plot widget updates
# 37     340       Image viewer levels sensitive to nan and inf
# 39     334                   Reconstruction by dilation hangs
# 42     328             Move the recon filter to backprojector
# 46     322                         Slices to multi frame tiff
# 50     315                             Revise skiplist dialog
# 53     310  MuhRec - add Exceptions when reference images ...
# 54     308       MuhRec - Crashing after "Get piercing point"
# 55     307                     KipTool - add rotation option
# 56     306          Add new defaults to polynomial correction
# 57     303                                 golden ratio order
# 58     299                 MuhRec doesn't delete CurrentRecon
# 59     298                          PyBind Imaging algorithms
# 60     297          Modules to produce citations in reporting
# 61     296           CBCT doesn't return correct attune coefs
# 62     295                              MuhRec: CBCT feedback
# 63     294  MuhRec - BB plugin option for single external ...
# 64     290                     Prepare for MuhRec release 4.1
# 71     282         Muhrec: implement inspection of references
# 72     281                  MuhRec: Revise center of rotation
# 73     280  MuhRec - golden ratio starting at different an...
# 74     278  MuhRec - load config files does not update the...
# 75     277                    Revise the MorphSpotCleanModule
# 76     276              MuhRec - add the pixel size estimator
# 79     271          KipTool -  saving fits in conversion tool
# 84     260                   FrameSplitter crashes on windows
# 88     255                      Update MuhRec plots to Charts
# 89     254                          MuhRec produce NaN slices
# 91     250         PixelIterator returns pixels outside image
# 94     247          KipTool - Ubuntu packaging after building
# 96     244                 KipTool- BBLogNorm RepairFillHoles
# 98     242       ROI doesn't work on KipTool conversion tools
#
#                    closed_at
# 7  2020-01-07 13:57:46+00:00
# 11 2020-01-10 08:20:13+00:00
# 13 2020-01-09 09:53:19+00:00
# 14 2020-01-10 08:19:52+00:00
# 17 2020-01-09 11:20:38+00:00
# 20 2019-11-15 15:46:24+00:00
# 24 2019-12-20 15:57:27+00:00
# 26 2020-01-10 09:12:59+00:00
# 31 2019-10-10 01:23:39+00:00
# 34 2019-10-10 14:07:59+00:00
# 37 2019-11-15 16:01:20+00:00
# 39 2019-11-22 06:46:11+00:00
# 42 2019-09-03 19:15:07+00:00
# 46 2019-07-11 12:28:33+00:00
# 50 2019-06-20 11:55:56+00:00
# 53 2019-11-15 14:25:33+00:00
# 54 2019-06-17 08:16:38+00:00
# 55 2020-01-10 08:21:52+00:00
# 56 2019-06-20 13:36:18+00:00
# 57 2019-11-15 14:32:38+00:00
# 58 2019-11-22 06:44:10+00:00
# 59 2020-01-10 08:15:10+00:00
# 60 2019-11-25 11:51:30+00:00
# 61 2020-01-10 08:14:34+00:00
# 62 2019-06-17 08:19:32+00:00
# 63 2020-01-10 08:16:32+00:00
# 64 2019-06-17 08:22:07+00:00
# 71 2020-01-12 07:44:43+00:00
# 72 2019-11-20 15:32:17+00:00
# 73 2019-05-03 13:02:50+00:00
# 74 2019-05-10 12:48:55+00:00
# 75 2019-05-10 07:17:27+00:00
# 76 2019-05-10 14:59:16+00:00
# 79 2019-04-25 07:56:50+00:00
# 84 2019-04-25 07:59:12+00:00
# 88 2019-03-05 09:13:13+00:00
# 89 2019-05-10 15:01:58+00:00
# 91 2019-09-27 07:40:18+00:00
# 94 2019-02-22 09:58:57+00:00
# 96 2019-02-22 09:59:14+00:00
# 98 2019-02-22 09:58:33+00:00

# %% [markdown]
# # Print list for github markdown

# %%
for index,issue in closedissues.iterrows() :
    print('- Issue',issue['number'], '- [',issue['title'],'](', issue['html_url'],')')
# Out:
# - Issue 381 - [ kipl::base::morphology LabelImage crashes on Win ]( https://github.com/neutronimaging/imagingsuite/issues/381 )
# - Issue 374 - [ BB - exception is not thrown when automatic segmentation fails ]( https://github.com/neutronimaging/imagingsuite/issues/374 )
# - Issue 371 - [ MuhRec: module dialogs don't open after merging issue123_configfiles ]( https://github.com/neutronimaging/imagingsuite/issues/371 )
# - Issue 370 - [ BB module, add automatic counting of external background images ]( https://github.com/neutronimaging/imagingsuite/issues/370 )
# - Issue 365 - [ MorphSpotClean crashes on windows ]( https://github.com/neutronimaging/imagingsuite/issues/365 )
# - Issue 360 - [ Add useful constants to be used in the TOF library ]( https://github.com/neutronimaging/imagingsuite/issues/360 )
# - Issue 355 - [ Wavelet ring cleaning crashing ]( https://github.com/neutronimaging/imagingsuite/issues/355 )
# - Issue 352 - [ Implement computation of numerical gradient ]( https://github.com/neutronimaging/imagingsuite/issues/352 )
# - Issue 346 - [ Add roi labels ]( https://github.com/neutronimaging/imagingsuite/issues/346 )
# - Issue 343 - [ Plot widget updates ]( https://github.com/neutronimaging/imagingsuite/issues/343 )
# - Issue 340 - [ Image viewer levels sensitive to nan and inf ]( https://github.com/neutronimaging/imagingsuite/issues/340 )
# - Issue 334 - [ Reconstruction by dilation hangs ]( https://github.com/neutronimaging/imagingsuite/issues/334 )
# - Issue 328 - [ Move the recon filter to backprojector ]( https://github.com/neutronimaging/imagingsuite/issues/328 )
# - Issue 322 - [ Slices to multi frame tiff ]( https://github.com/neutronimaging/imagingsuite/issues/322 )
# - Issue 315 - [ Revise skiplist dialog ]( https://github.com/neutronimaging/imagingsuite/issues/315 )
# - Issue 310 - [ MuhRec - add Exceptions when reference images and projection data have different sizes ]( https://github.com/neutronimaging/imagingsuite/issues/310 )
# - Issue 308 - [ MuhRec - Crashing after "Get piercing point" ]( https://github.com/neutronimaging/imagingsuite/issues/308 )
# - Issue 307 - [ KipTool - add rotation option  ]( https://github.com/neutronimaging/imagingsuite/issues/307 )
# - Issue 306 - [ Add new defaults to polynomial correction ]( https://github.com/neutronimaging/imagingsuite/issues/306 )
# - Issue 303 - [ golden ratio order ]( https://github.com/neutronimaging/imagingsuite/issues/303 )
# - Issue 299 - [ MuhRec doesn't delete CurrentRecon ]( https://github.com/neutronimaging/imagingsuite/issues/299 )
# - Issue 298 - [ PyBind Imaging algorithms ]( https://github.com/neutronimaging/imagingsuite/issues/298 )
# - Issue 297 - [ Modules to produce citations in reporting ]( https://github.com/neutronimaging/imagingsuite/issues/297 )
# - Issue 296 - [ CBCT doesn't return correct attune coefs ]( https://github.com/neutronimaging/imagingsuite/issues/296 )
# - Issue 295 - [ MuhRec: CBCT feedback ]( https://github.com/neutronimaging/imagingsuite/issues/295 )
# - Issue 294 - [ MuhRec - BB plugin option for single external BB images ]( https://github.com/neutronimaging/imagingsuite/issues/294 )
# - Issue 290 - [ Prepare for MuhRec release 4.1 ]( https://github.com/neutronimaging/imagingsuite/issues/290 )
# - Issue 282 - [ Muhrec: implement inspection of references ]( https://github.com/neutronimaging/imagingsuite/issues/282 )
# - Issue 281 - [ MuhRec: Revise center of rotation ]( https://github.com/neutronimaging/imagingsuite/issues/281 )
# - Issue 280 - [ MuhRec - golden ratio starting at different angle than 0 ]( https://github.com/neutronimaging/imagingsuite/issues/280 )
# - Issue 278 - [ MuhRec - load config files does not update the ROIs ]( https://github.com/neutronimaging/imagingsuite/issues/278 )
# - Issue 277 - [ Revise the MorphSpotCleanModule ]( https://github.com/neutronimaging/imagingsuite/issues/277 )
# - Issue 276 - [ MuhRec - add the pixel size estimator ]( https://github.com/neutronimaging/imagingsuite/issues/276 )
# - Issue 271 - [ KipTool -  saving fits in conversion tool ]( https://github.com/neutronimaging/imagingsuite/issues/271 )
# - Issue 260 - [ FrameSplitter crashes on windows ]( https://github.com/neutronimaging/imagingsuite/issues/260 )
# - Issue 255 - [ Update MuhRec plots to Charts ]( https://github.com/neutronimaging/imagingsuite/issues/255 )
# - Issue 254 - [ MuhRec produce NaN slices ]( https://github.com/neutronimaging/imagingsuite/issues/254 )
# - Issue 250 - [ PixelIterator returns pixels outside image ]( https://github.com/neutronimaging/imagingsuite/issues/250 )
# - Issue 247 - [ KipTool - Ubuntu packaging after building ]( https://github.com/neutronimaging/imagingsuite/issues/247 )
# - Issue 244 - [ KipTool- BBLogNorm RepairFillHoles ]( https://github.com/neutronimaging/imagingsuite/issues/244 )
# - Issue 242 - [ ROI doesn't work on KipTool conversion tools ]( https://github.com/neutronimaging/imagingsuite/issues/242 )

# %%
i2=pd.read_json("https://api.github.com/repos/neutronimaging/imagingsuite/issues?state=closed&page=1&since=\"2019-05-28T10:00:00Z\"&per_page=400")

# %%
for index,issue in i2.iterrows() :
    print('- Issue',issue['number'], '- [',issue['title'],'](', issue['html_url'],')')
# Out:
# - Issue 388 - [ Issue39 tunespotclean ]( https://github.com/neutronimaging/imagingsuite/pull/388 )
# - Issue 387 - [ Issue296 cbct ]( https://github.com/neutronimaging/imagingsuite/pull/387 )
# - Issue 386 - [ Issue365 spotcleancrash ]( https://github.com/neutronimaging/imagingsuite/pull/386 )
# - Issue 385 - [ Issue371 cfgdlg linux ]( https://github.com/neutronimaging/imagingsuite/pull/385 )
# - Issue 384 - [ Issue374 segm excep ]( https://github.com/neutronimaging/imagingsuite/pull/384 )
# - Issue 383 - [ Removed legacy externals ]( https://github.com/neutronimaging/imagingsuite/pull/383 )
# - Issue 382 - [ Issue381 lblimgcrash ]( https://github.com/neutronimaging/imagingsuite/pull/382 )
# - Issue 381 - [ kipl::base::morphology LabelImage crashes on Win ]( https://github.com/neutronimaging/imagingsuite/issues/381 )
# - Issue 380 - [ Fixed the crash bug of stripe filter. ]( https://github.com/neutronimaging/imagingsuite/pull/380 )
# - Issue 379 - [ Issue329 bind recon engine ]( https://github.com/neutronimaging/imagingsuite/pull/379 )
# - Issue 376 - [ Issue295 ext1 bb ]( https://github.com/neutronimaging/imagingsuite/pull/376 )
# - Issue 374 - [ BB - exception is not thrown when automatic segmentation fails ]( https://github.com/neutronimaging/imagingsuite/issues/374 )
# - Issue 373 - [ Issue298 py bind imaging alg ]( https://github.com/neutronimaging/imagingsuite/pull/373 )
# - Issue 371 - [ MuhRec: module dialogs don't open after merging issue123_configfiles ]( https://github.com/neutronimaging/imagingsuite/issues/371 )
# - Issue 370 - [ BB module, add automatic counting of external background images ]( https://github.com/neutronimaging/imagingsuite/issues/370 )
# - Issue 367 - [ Issue23 configfiles ]( https://github.com/neutronimaging/imagingsuite/pull/367 )
# - Issue 366 - [ Issue297 citations ]( https://github.com/neutronimaging/imagingsuite/pull/366 )
# - Issue 365 - [ MorphSpotClean crashes on windows ]( https://github.com/neutronimaging/imagingsuite/issues/365 )
# - Issue 364 - [ Added extra check if the config is still present ]( https://github.com/neutronimaging/imagingsuite/pull/364 )
# - Issue 361 - [ Issue360 mathconstants ]( https://github.com/neutronimaging/imagingsuite/pull/361 )
# - Issue 360 - [ Add useful constants to be used in the TOF library ]( https://github.com/neutronimaging/imagingsuite/issues/360 )
# - Issue 359 - [ Issue235 contrast ]( https://github.com/neutronimaging/imagingsuite/pull/359 )
# - Issue 358 - [ Issue354 sav gol filter ]( https://github.com/neutronimaging/imagingsuite/pull/358 )
# - Issue 357 - [ SavGol filter is implemented ]( https://github.com/neutronimaging/imagingsuite/pull/357 )
# - Issue 355 - [ Wavelet ring cleaning crashing ]( https://github.com/neutronimaging/imagingsuite/issues/355 )
# - Issue 353 - [ Issue352 numericalgradient ]( https://github.com/neutronimaging/imagingsuite/pull/353 )
# - Issue 352 - [ Implement computation of numerical gradient ]( https://github.com/neutronimaging/imagingsuite/issues/352 )
# - Issue 351 - [ added source files from lmfit ]( https://github.com/neutronimaging/imagingsuite/pull/351 )
# - Issue 349 - [ Issue235 contrast ]( https://github.com/neutronimaging/imagingsuite/pull/349 )
# - Issue 348 - [ Added support for generic plot series. ]( https://github.com/neutronimaging/imagingsuite/pull/348 )
# - Issue 347 - [ Revised roi labels ]( https://github.com/neutronimaging/imagingsuite/pull/347 )
# - Issue 346 - [ Add roi labels ]( https://github.com/neutronimaging/imagingsuite/issues/346 )
# - Issue 345 - [ Issue235 contrast ]( https://github.com/neutronimaging/imagingsuite/pull/345 )
# - Issue 344 - [ Added axis labels ]( https://github.com/neutronimaging/imagingsuite/pull/344 )
# - Issue 343 - [ Plot widget updates ]( https://github.com/neutronimaging/imagingsuite/issues/343 )
# - Issue 342 - [ Issue187 pixel iterator (intermediate II) ]( https://github.com/neutronimaging/imagingsuite/pull/342 )
# - Issue 341 - [ Issue340 viewer inf na n ]( https://github.com/neutronimaging/imagingsuite/pull/341 )
# - Issue 340 - [ Image viewer levels sensitive to nan and inf ]( https://github.com/neutronimaging/imagingsuite/issues/340 )
# - Issue 337 - [ Issue187 pixel iterator ]( https://github.com/neutronimaging/imagingsuite/pull/337 )
# - Issue 334 - [ Reconstruction by dilation hangs ]( https://github.com/neutronimaging/imagingsuite/issues/334 )
# - Issue 333 - [ Issue328 proj filter ]( https://github.com/neutronimaging/imagingsuite/pull/333 )
# - Issue 331 - [ Correction of bugs of BBmodule in KipTool ]( https://github.com/neutronimaging/imagingsuite/pull/331 )
# - Issue 328 - [ Move the recon filter to backprojector ]( https://github.com/neutronimaging/imagingsuite/issues/328 )
# - Issue 327 - [ Fixed enum spelling error for multi frame tiff ]( https://github.com/neutronimaging/imagingsuite/pull/327 )
# - Issue 324 - [ Issue322 slice2vol ]( https://github.com/neutronimaging/imagingsuite/pull/324 )
# - Issue 323 - [ Issue298 py bind imaging alg ]( https://github.com/neutronimaging/imagingsuite/pull/323 )
# - Issue 322 - [ Slices to multi frame tiff ]( https://github.com/neutronimaging/imagingsuite/issues/322 )
# - Issue 320 - [ Issue298 py bind imaging alg ]( https://github.com/neutronimaging/imagingsuite/pull/320 )
# - Issue 317 - [ Added default parameters for a 3rd order polynomial ]( https://github.com/neutronimaging/imagingsuite/pull/317 )
# - Issue 316 - [ Skip list updated ]( https://github.com/neutronimaging/imagingsuite/pull/316 )
# - Issue 315 - [ Revise skiplist dialog ]( https://github.com/neutronimaging/imagingsuite/issues/315 )
# - Issue 314 - [ Fixed crashing PP dialog ]( https://github.com/neutronimaging/imagingsuite/pull/314 )
# - Issue 313 - [ Implemented issue 295 ]( https://github.com/neutronimaging/imagingsuite/pull/313 )
# - Issue 310 - [ MuhRec - add Exceptions when reference images and projection data have different sizes ]( https://github.com/neutronimaging/imagingsuite/issues/310 )
# - Issue 308 - [ MuhRec - Crashing after "Get piercing point" ]( https://github.com/neutronimaging/imagingsuite/issues/308 )
# - Issue 307 - [ KipTool - add rotation option  ]( https://github.com/neutronimaging/imagingsuite/issues/307 )
# - Issue 306 - [ Add new defaults to polynomial correction ]( https://github.com/neutronimaging/imagingsuite/issues/306 )
# - Issue 303 - [ golden ratio order ]( https://github.com/neutronimaging/imagingsuite/issues/303 )
# - Issue 299 - [ MuhRec doesn't delete CurrentRecon ]( https://github.com/neutronimaging/imagingsuite/issues/299 )
# - Issue 298 - [ PyBind Imaging algorithms ]( https://github.com/neutronimaging/imagingsuite/issues/298 )
# - Issue 297 - [ Modules to produce citations in reporting ]( https://github.com/neutronimaging/imagingsuite/issues/297 )
# - Issue 296 - [ CBCT doesn't return correct attune coefs ]( https://github.com/neutronimaging/imagingsuite/issues/296 )
# - Issue 295 - [ MuhRec: CBCT feedback ]( https://github.com/neutronimaging/imagingsuite/issues/295 )
# - Issue 294 - [ MuhRec - BB plugin option for single external BB images ]( https://github.com/neutronimaging/imagingsuite/issues/294 )
# - Issue 290 - [ Prepare for MuhRec release 4.1 ]( https://github.com/neutronimaging/imagingsuite/issues/290 )
# - Issue 282 - [ Muhrec: implement inspection of references ]( https://github.com/neutronimaging/imagingsuite/issues/282 )
# - Issue 281 - [ MuhRec: Revise center of rotation ]( https://github.com/neutronimaging/imagingsuite/issues/281 )
# - Issue 250 - [ PixelIterator returns pixels outside image ]( https://github.com/neutronimaging/imagingsuite/issues/250 )
# - Issue 235 - [ NIQA issues Contrast Analysis ]( https://github.com/neutronimaging/imagingsuite/issues/235 )
# - Issue 166 - [ User documentation for KipTool ]( https://github.com/neutronimaging/imagingsuite/issues/166 )
# - Issue 162 - [ MuhRec Open saved config doesn't update correctly  ]( https://github.com/neutronimaging/imagingsuite/issues/162 )
# - Issue 135 - [ Bragg edge fitting  ]( https://github.com/neutronimaging/imagingsuite/issues/135 )
# - Issue 134 - [ Implement edge function fitting ]( https://github.com/neutronimaging/imagingsuite/issues/134 )
# - Issue 130 - [ CBCT writes detector pixel size in slices ]( https://github.com/neutronimaging/imagingsuite/issues/130 )
# - Issue 95 - [ ImageViewerWidget data interval with NaNs and Infs ]( https://github.com/neutronimaging/imagingsuite/issues/95 )
# - Issue 39 - [ Morph spot clean performance tuning ]( https://github.com/neutronimaging/imagingsuite/issues/39 )
# - Issue 23 - [ Config files compatible cross platform ]( https://github.com/neutronimaging/imagingsuite/issues/23 )
